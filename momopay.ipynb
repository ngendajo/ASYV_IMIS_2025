# %%
import requests
from requests.auth import HTTPBasicAuth

#Replace with your actual keys
consumer_key = "AaR4Hj5A5gDURQW6rDTdVpT1d5TZWlkl"
consumer_secret = "y7Vb5GGaFKu0m6XB"

url = "https://proxy.momoapi.mtn.com/collection/token/"
headers = {
    "Content-Type": "application/x-www-form-urlencoded"
}
data = {
    "grant_type": "client_credentials"
}

response = requests.post(
    url,
    headers=headers,
    data=data,
    auth=HTTPBasicAuth(consumer_key, consumer_secret)
)

print("Status:", response.status_code)
print("Response:", response.json())
# Out:
# Status: 401
# Response: {'statusCode': 401, 'message': 'Access denied due to missing subscription key. Make sure to include subscription key when making requests to an API.'}
